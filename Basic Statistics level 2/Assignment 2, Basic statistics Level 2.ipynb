# %% [markdown]
# #  Assignment-2 ,Set-1, Question no. 1

# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
import seaborn as sns

# %%
#import warnings
import warnings 
warnings.filterwarnings('ignore')

# %%
x=pd.Series([24.23,25.53,25.41,24.14,29.62,28.25,25.81,24.39,40.26,32.95,91.36,25.99,39.42,26.71,35.00])

# %%
Name=['Allied Signal','Bankers Trust','General Mills','ITT Industries','J.P. Morgan & Co.','Lehman Brothers','Marriott','MCI','Merrill Lynch','Microsoft','Morgan Stanley','Sun Microsystems','Travelers','US Airways','Warner-Lambert']

# %%
df = pd.DataFrame(list(zip(x,Name)), columns =['Measure X', 'Name of company'])
df
# Out:
#     Measure X    Name of company
# 0       24.23      Allied Signal
# 1       25.53      Bankers Trust
# 2       25.41      General Mills
# 3       24.14     ITT Industries
# 4       29.62  J.P. Morgan & Co.
# 5       28.25    Lehman Brothers
# 6       25.81           Marriott
# 7       24.39                MCI
# 8       40.26      Merrill Lynch
# 9       32.95          Microsoft
# 10      91.36     Morgan Stanley
# 11      25.99   Sun Microsystems
# 12      39.42          Travelers
# 13      26.71         US Airways
# 14      35.00     Warner-Lambert

# %%
#pie plot
plt.figure(figsize=(18,9))
plt.pie(x,labels=Name,autopct='%1.1f%%', shadow=True)
plt.title('Name of the companies with respect to x',fontsize=20,color='red')

plt.show()

# %%
#Bar plot
plt.bar(Name,x,edgecolor='black')
plt.title('Name of the companies with respect to X')
plt.xlabel('Name of the companies ')
plt.xticks(rotation=90)
plt.ylabel('Measure X')
plt.figure(figsize=(18,19))
plt.show()

# %%
#Finding outliers using Boxplot
sns.boxplot(x)
plt.show()

# %%
#Calculating mean
x.mean()
# Out:
# 33.27133333333333

# %%
# Calculating standard deviation
x.std()
# Out:
# 16.945400921222028

# %%
# Calculating variance
x.var()
# Out:
# 287.1466123809524

# %%
x=pd.Series(x)
Q1=np.quantile(x,0.25)
Q3=np.quantile(x,0.75)
IQR=Q3-Q1
Upper_bound=Q3+(1.5*IQR)
Lower_bound=Q1-(1.5*IQR)
med=np.median(x)
print("First Quantile=",Q1,"Second Quantile=",med, "Third Quantile=",Q3,"Inter Quantile Range=",IQR,"Upper Whisker=",Upper_bound,"Lower Whisker=",Lower_bound)
Outliers=x[(x<=Lower_bound) | (x>=Upper_bound)]
print("The Outlier in the boxplot:",Outliers)
# Out:
# First Quantile= 25.47 Second Quantile= 26.71 Third Quantile= 33.975 Inter Quantile Range= 8.505000000000003 Upper Whisker= 46.7325 Lower Whisker= 12.712499999999995
# The Outlier in the boxplot: 10    91.36
# dtype: float64

# %% [markdown]
# #  Assignment-2, Set-2, Question no. 1

# %%
from scipy import stats
from scipy.stats import norm

# %% [markdown]
# Find Z-score at X=50, where Z=(X - µ) / σ

# %%
Z=(50-45)/8
Z
# Out:
# 0.625

# %% [markdown]
# Find pobability P(X>50)=1-stats.norm.cdf(abs(Z_score))

# %%
1-stats.norm.cdf(abs(0.625))
# Out:
# 0.26598552904870054

# %% [markdown]
# Find probability P(X<=50), p_value=stats.norm.cdf(abs(Z_score))

# %%
p_value=stats.norm.cdf(abs(0.625))
p_value
# Out:
# 0.7340144709512995

# %% [markdown]
# P(X>50)=1-P(X<=50)

# %%
1-0.734
# Out:
# 0.266

# %% [markdown]
# # Assignment-2, Set-2, Question no.2

# %% [markdown]
# No. of clerical employees at an indurance claims center=400,mean=38,standard deviation=6
# Z score=(Value-Mean)/SD
# A. More employeesat the processing center are older than 44 and between 38 and 44

# %%
from scipy import stats
from scipy.stats import norm

# %%
# P(X>44); Employees older than 44 years of age
1-stats.norm.cdf(44,loc=38, scale=6)
# Out:
# 0.15865525393145707

# %%
#P(38)
stats.norm.cdf(44,38,6)-stats.norm.cdf(38,38,6)
# Out:
# 0.3413447460685429

# %% [markdown]
# B. A training program for employees under the age of 30 at the center would be expected to attract about 36 employees.

# %%
# P(X<30); Employees under 30 years of age
stats.norm.cdf(30,38,6)
# Out:
# 0.09121121972586788

# %%
# No.of employees attending training program from 400 nos. is N*P(X,30)
400*stats.norm.cdf(30,38,6)
# Out:
# 36.484487890347154

# %% [markdown]
# #  Set - 2, Question no.4

# %%
from scipy import stats
from scipy.stats import norm

# %% [markdown]
# X=N(100,200**2)

# %%
stats.norm.interval(0.99,100,20)
# Out:
# (48.48341392902199, 151.516586070978)

# %% [markdown]
# a=48.48341392902199 and b=48.48341392902199
# hence option D is correct

# %% [markdown]
# # Set-2, Question no.5

# %%
import numpy as np
from scipy import stats
from scipy.stats import norm

# %% [markdown]
# Mean profils from two different divisions of a company = Mean1 + Mean2

# %% [markdown]
# Mean=5+7
# print("Mean Profit =",Mean*45,"Million")

# %% [markdown]
# Variance of profit from two different divisions of a company = SD^2=SD1^2+SD2^2

# %%
SD=(3^2)+(4^2)
print("standard Deviation=",SD*45,"Million")
# Out:
# standard Deviation= 315 Million

# %% [markdown]
# A. Specify a Rupee range(centered on the mean) such that it contains 95% probability for the annual profit of the company.

# %%
print("Range in Rs=",(stats.norm.interval(0.95,540,315)),"Million")
# Out:
# Range in Rs= (-77.38865513011706, 1157.388655130117) Million

# %% [markdown]
# B.Specify the 5th percentile of profit (in Rupees) for the company, To compute 5th Percentile, we use the formula X=μ + Zσ; wherein from Z table, 5 percentile=-1.64

# %%
X=540+(-1.64)*(315)
print("5th percentile of profit =",X,"Million")
# Out:
# 5th percentile of profit = 23.399999999999977 Million

# %% [markdown]
# C.Which of the two divisions has a larger probability of making a loss in a given year?

# %%
#probability of Division 1 making a loss p(X<0)
stats.norm.cdf(0,5,3)
# Out:
# 0.0477903522728147

# %%
#probability of division 2 making a loss P(X<0)
stats.norm.cdf(0,7,4)
# Out:
# 0.040059156863817086

# %% [markdown]
# # Set-3 Question no. 5

# %%
#import libraries
import statsmodels.api as smf

# %% [markdown]
# null_hypothesis>=5% alternate hypothesis<5%

# %%
p_hat =0.46
p=0.05
n=2000

# z_score=p_hat-p/(p(1-p)/n)**0.5
z_score =(p_hat-p)/(np.sqrt((p*(1-p))/n))
z_score
                   
p_value=stats.norm.sf(0.821)
p_value
# Out:
# 0.20582313410777142

# %% [markdown]
# Find pobability assuming null hypothesis, so as to compare with Type-1 error α = 0.05

# %%
if p_value>0.05:
    print ("No: Microsoft could not conclude that Mozilla firefox has a less than 5% share of the market even if the sample were based on 2000 users")
else:
    print("Yes")
# Out:
# No: Microsoft could not conclude that Mozilla firefox has a less than 5% share of the market even if the sample were based on 2000 users

# %% [markdown]
# # Set-4 Question no.-3

# %%
#import libraries
import numpy as np
import statsmodels.api as smf

# %%
Mean=50
Std=40
n=100
d_f=100-1 #degrees of freedom
#the probability that there will be an investigation,
#if the mean transaction amount increases more than 55 USD or less than 45 USD
# no intvestigation if the mean transaction amount remains between 45 to 55 USD

# we will go for t-distribution as population standard deviation is unknown
 
t_fortyfive=(45-50)/(40/np.sqrt(100))
t_fiftyfive=(55-50)/(40/np.sqrt(100))

fortyfive=stats.t.cdf(t_fortyfive,df=d_f)
fiftyfive=stats.t.cdf(t_fiftyfive,d_f)

prob=fiftyfive-fortyfive

np.round(stats.t.interval(alpha=prob,df=d_f,loc=Mean,scale=Std/np.sqrt(n)))

print("The probability that in any given week, there will be an investigation is",np.round((1-prob)*100,1),'%')
# Out:
# The probability that in any given week, there will be an investigation is 21.4 %

# %% [markdown]
# #  Set-4, Question no. 4

# %%
x_bar=45
std=40
mew=50
t=np.round(stats.t.ppf(0.025,df=249),2)
t
# t_value=(x_bar-mew)/(sampl_std/n**0.5)
# t=45-50 or z=55-50 z=+/-5

# t=5/(40/n**0.5)
# n=(sample_standard_deviation*tscore)/(sample_mean=population_mean)
n=((std*abs(t))/(5))**2

print("The Auditors would like to maintain the probability of investigation to 5%, they should sample',np.round(n,),'transactions if they do not want ")
df=n-1
print(n,df)

np.round(stats.t.interval(alpha=0.95,df=df,loc=mew,scale=std/np.sqrt(n)),)
# Out:
# The Auditors would like to maintain the probability of investigation to 5%, they should sample',np.round(n,),'transactions if they do not want
# 248.3776 247.3776
# array([45., 55.])
